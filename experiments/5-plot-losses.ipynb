# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../ClassificationNet-zero-grad-256-500-prior-inverted-non-smooth-alpha-10.0-p-2.0/losses.csv')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.iloc[100:].plot()
# Out:
# <Axes: >
