# %%
from src.models import model_for_name
from src.experiments import load_model


model = model_for_name('ClassificationNet')(num_classes=10, configuration=[[12, 2], [24, 2], [48, 2]], image_channels=1, activation='GELU')

# %%
from torchinfo import summary


summary(model, input_size=(1, 1, 28, 28))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ClassificationNet                             [1, 10]                   --
# ├─Sequential: 1-1                             [1, 48, 31, 31]           --
# │    └─ModuleList: 2-1                        --                        --
# │    │    └─Conv2d: 3-1                       [1, 12, 28, 28]           120
# │    │    └─ConvNormAct: 3-2                  [1, 12, 29, 29]           2,340
# │    │    └─ConvNormAct: 3-3                  [1, 12, 29, 29]           1,332
# │    │    └─ConvNormAct: 3-4                  [1, 12, 29, 29]           1,332
# │    │    └─ConvNormAct: 3-5                  [1, 24, 30, 30]           4,680
# │    │    └─ConvNormAct: 3-6                  [1, 24, 30, 30]           5,256
# │    │    └─ConvNormAct: 3-7                  [1, 24, 30, 30]           5,256
# │    │    └─ConvNormAct: 3-8                  [1, 48, 31, 31]           18,576
# │    │    └─ConvNormAct: 3-9                  [1, 48, 31, 31]           20,880
# │    │    └─ConvNormAct: 3-10                 [1, 48, 31, 31]           20,880
# │    │    └─Conv2d: 3-11                      [1, 48, 31, 31]           20,784
# ├─Linear: 1-2                                 [1, 10]                   490
# ===============================================================================================
# Total params: 101,926
# Trainable params: 101,926
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 95.47
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 4.18
# Params size (MB): 0.41
# Estimated Total Size (MB): 4.59
# ===============================================================================================
