# %%
from src.models import model_for_name
from src.experiments import load_model


model = model_for_name('ClassificationNet')(num_classes=10, configuration=[[12, 2], [12, 2]], image_channels=1, activation='GELU')

# %%
from torchinfo import summary


summary(model, input_size=(1, 1, 28, 28))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ClassificationNet                             [1, 10]                   --
# ├─Sequential: 1-1                             [1, 12, 30, 30]           --
# │    └─ModuleList: 2-1                        --                        --
# │    │    └─Conv2d: 3-1                       [1, 12, 28, 28]           120
# │    │    └─ConvNormAct: 3-2                  [1, 12, 29, 29]           2,340
# │    │    └─ConvNormAct: 3-3                  [1, 12, 29, 29]           1,332
# │    │    └─ConvNormAct: 3-4                  [1, 12, 29, 29]           1,332
# │    │    └─ConvNormAct: 3-5                  [1, 12, 30, 30]           2,340
# │    │    └─ConvNormAct: 3-6                  [1, 12, 30, 30]           1,332
# │    │    └─ConvNormAct: 3-7                  [1, 12, 30, 30]           1,332
# │    │    └─Conv2d: 3-8                       [1, 12, 30, 30]           1,308
# ├─Linear: 1-2                                 [1, 10]                   130
# ===============================================================================================
# Total params: 11,566
# Trainable params: 11,566
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 9.86
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.16
# Params size (MB): 0.05
# Estimated Total Size (MB): 1.21
# ===============================================================================================

# %%
model
# Out:
# ClassificationNet(
#   (loss): CrossEntropyLoss()
#   (main): Sequential(
#     (main): ModuleList(
#       (0): Conv2d(1, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ConvNormAct(
#         (blocks): Sequential(
#           (0): Conv2d(12, 12, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#       )
#       (2-3): 2 x ConvNormAct(
#         (blocks): Sequential(
#           (0): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#       )
#       (4): ConvNormAct(
#         (blocks): Sequential(
#           (0): Conv2d(12, 24, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#       )
#       (5-6): 2 x ConvNormAct(
#         (blocks): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#       )
#       (7): ConvNormAct(
#         (blocks): Sequential(
#           (0): Conv2d(24, 48, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#       )
#       (8-9): 2 x ConvNormAct(
#         (blocks): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#       )
#       (10): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (classifier): Linear(in_features=48, out_features=10, bias=True)
# )
